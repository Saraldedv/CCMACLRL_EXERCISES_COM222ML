# %% [markdown]
# <a href="https://colab.research.google.com/github/Saraldedv/CCMACLRL_EXERCISES_COM222ML/blob/main/Copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #EXERCISE 1

# %% [markdown]
# ##Functions

# %%
# !pip install pandas
# !pip install matplotlib

# %%
def myname():
  print("Denmar")

# %%
myname()
# Out:
# Denmar

# %% [markdown]
# ##Lists

# %%
fruits = [ "apple", "banana", "orange", "Lemon", "grapes"]

# %%
fruits
# Out:
# ['apple', 'banana', 'orange', 'Lemon', 'grapes']

# %%
for i in fruits:
  print (i)
# Out:
# apple
# banana
# orange
# Lemon
# grapes

# %%
mynewlist2 = []
if "e" in i:
  mynewlist2.append(i)

# %%
mynewlist2
# Out:
# ['grapes']

# %% [markdown]
# ##List comprehension

# %%
mynewlist = [i for i in fruits]

# %%
mynewlist
# Out:
# ['apple', 'banana', 'orange', 'Lemon', 'grapes']

# %%
mynewlist2 =[i for i in fruits if "e" in i]

# %%
mynewlist2
# Out:
# ['apple', 'orange', 'Lemon', 'grapes']

# %% [markdown]
# ##Map

# %%
mynumbers = [1,2,3,4,5]

# %%
def multiply(num):
  return num*2

# %%
mynewnumber = list(map(multiply, mynumbers))
mynewnumber
# Out:
# [2, 4, 6, 8, 10]

# %% [markdown]
# ##Lambda

# %%
answer = lambda x:x*7
print(answer(9))
# Out:
# 63

# %% [markdown]
# ##Pandas

# %%
import pandas as pd

# %%
dataframe = pd.read_excel("RECORDS.xlsx")

# %%
dataframe
# Out:
#     Height   Weight  Age
# 0       167      70   22
# 1       166      69   20
# 2       155      43   21
# 3       157      65   20
# 4       179      73   21
# 5       160      80   20
# 6       153      57   24
# 7       152      55   19
# 8       158      63   21
# 9       160      52   20
# 10      160      80   20

# %%
dataframe.head()
# Out:
#    Height   Weight  Age
# 0      167      70   22
# 1      166      69   20
# 2      155      43   21
# 3      157      65   20
# 4      179      73   21

# %%
dataframe.tail()
# Out:
#    Height   Weight  Age
# 5      160      80   20
# 6      153      57   24
# 7      152      55   19
# 8      158      63   21
# 9      160      52   20

# %%
dataframe.value_counts()
# Out:
# Height   Weight  Age
# 160      80      20     2
# 152      55      19     1
# 153      57      24     1
# 155      43      21     1
# 157      65      20     1
# 158      63      21     1
# 160      52      20     1
# 166      69      20     1
# 167      70      22     1
# 179      73      21     1
# Name: count, dtype: int64

# %%
dataframe.drop_duplicates(inplace=True)

# %%
dataframe.value_counts()
# Out:
# Height   Weight  Age
# 152      55      19     1
# 153      57      24     1
# 155      43      21     1
# 157      65      20     1
# 158      63      21     1
# 160      52      20     1
#          80      20     1
# 166      69      20     1
# 167      70      22     1
# 179      73      21     1
# Name: count, dtype: int64

# %%
dataframe.iloc[6]
# Out:
# Height     153
# Weight      57
# Age         24
# Name: 6, dtype: int64

# %%
dataframe.describe()
# Out:
#           Height      Weight        Age
# count   10.000000  10.000000  10.000000
# mean   160.700000  62.700000  20.800000
# std      8.111035  11.045864   1.398412
# min    152.000000  43.000000  19.000000
# 25%    155.500000  55.500000  20.000000
# 50%    159.000000  64.000000  20.500000
# 75%    164.500000  69.750000  21.000000
# max    179.000000  80.000000  24.000000

# %%
dataframe.shape
# Out:
# (10, 3)

# %%
dataframe.drop(columns=["Weight"], inplace=True)

# %%
dataframe
# Out:
#    Height
# 0      167
# 1      166
# 2      155
# 3      157
# 4      179
# 5      160
# 6      153
# 7      152
# 8      158
# 9      160

# %% [markdown]
# ##Matplotlib

# %%
from matplotlib import pyplot as plt

# %%
X1 = [1,2,3,4,5]

# %%
plt.plot(X1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
X2 = [6,7,8,9,10]

# %%
plt.plot(X1)
plt.plot(X2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
